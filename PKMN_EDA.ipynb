# %% [markdown]
# ## HEY GUYS HOW'S IT GOING
# #### I found this pretty cool dataset of all Pokémon up to gen 9. I'm a huge Pokémon fan so I thought I would explore this dataset, brush up on my data visualization skills, and employ some cool machine learning techniques.
# #### My favorite Pokémon is Litwick. Here he is:

# %% [markdown]
# <img src="litwick_plush.webp" width=400px height=400px />

# %%
#imports
import pandas as pd
import numpy as np

# %%
# read in the dataset
pkmn = pd.read_csv("pokemon_combined.csv")

# %%
pkmn
# Out:
#               Name             Type              Species  Height  Weight  \
# 0        Bulbasaur     Grass Poison         Seed Pokémon     0.7     6.9
# 1          Ivysaur     Grass Poison         Seed Pokémon     1.0    13.0
# 2         Venusaur     Grass Poison         Seed Pokémon     2.4   155.5
# 3       Charmander             Fire       Lizard Pokémon     0.6     8.5
# 4       Charmeleon             Fire        Flame Pokémon     1.1    19.0
# ...            ...              ...                  ...     ...     ...
# 1009   Raging Bolt  Electric Dragon      Paradox Pokémon     5.2   480.0
# 1010  Iron Boulder     Rock Psychic      Paradox Pokémon     1.5   162.5
# 1011    Iron Crown    Steel Psychic      Paradox Pokémon     1.6   156.0
# 1012     Terapagos           Normal         Tera Pokémon     1.7    77.0
# 1013     Pecharunt     Poison Ghost  Subjugation Pokémon     0.3     0.3
#
#                                     Abilities  Catch rate  Base Friendship  \
# ...

# %% [markdown]
# ### Okay, first thing I see is that this is fully updated- yippee. Second thing: abilities and gender columns are messy. Need to clean those up. Some Pokémon have more than one abilities. One of these additional abilities may also be "hidden". This distinction is important.

# %% [markdown]
# ### Ideas for visualization:
# ### - distribution of types by weight
# ### - does a slow exp gain necessarily mean a stronger Pokémon? i.e. is a longer exp grind worth it usually
